# %% [markdown]
# ## 1) Import library yang dibutuhkan

# %%
# data analysis
import numpy as np
import pandas as pd

# visualisasi
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Eksplorasi Data
# Membaca data menggunakan `pd.read_csv` dan melihat informasi data dengan menggunakan function `describe()`.

# %%
train = pd.read_csv("../datasets/train.csv")
test = pd.read_csv("../datasets/test.csv")

train.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# ## 3) Data Analysis
# Melihat fitur-fitur pada data

# %%
#get a list of the features within the dataset
print(train.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.sample(5) # melihat sample 5 data pertama dari dataset
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 81            82         1       3     Sheerlinck, Mr. Jan Baptist    male
# 445          446         1       1       Dodge, Master. Washington    male
# 448          449         1       3  Baclini, Miss. Marie Catherine  female
# 212          213         0       3          Perkin, Mr. John Henry    male
# 800          801         0       2            Ponesell, Mr. Martin    male
#
#       Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 81   29.0      0      0     345779   9.5000   NaN        S
# 445   4.0      0      2      33638  81.8583   A34        S
# 448   5.0      2      1       2666  19.2583   NaN        C
# 212  22.0      0      0  A/5 21174   7.2500   NaN        S
# 800  34.0      0      0     250647  13.0000   NaN        S

# %% [markdown]
# * **Numerical Features:** Age (Continuous), Fare (Continuous), SibSp (Discrete), Parch (Discrete)
# * **Categorical Features:** Survived, Sex, Embarked, Pclass
# * **Alphanumeric Features:** Ticket, Cabin
#
# #### Tipe data dari setiap fitur
# * Survived: int
# * Pclass: int
# * Name: string
# * Sex: string
# * Age: float
# * SibSp: int
# * Parch: int
# * Ticket: string
# * Fare: float
# * Cabin: string
# * Embarked: string

# %%
train.describe(include = "all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# #### Insights:
# - terdapat 891 penumpang pada data training set
# - pada fitur *Age*, *Cabin*, dan *Embarked* terdapat data yang hilang

# %%
# melihat berapa banyak data null pada train
print(pd.isnull(train).sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Prediksi sementara berdasarkan fitur
# - Sex = wanita lebih mungkin untuk selamat
# - SibSp / Parch = orang yang pergi sendirian lebih mungkin untuk selamat
# - Age = anak kecil lebih mungkin untuk selamat
# - Pclass = orang dengan kelas ekonomi yang lebih tinggi lebih mungkin untuk selamat

# %% [markdown]
# ## 4) Visualisasi Data
# Lakukan visualisasi data terhadap masing-masing fitur untuk memastikan apakah prediksi kita di atas benar.

# %% [markdown]
# ### Sex

# %%
sns.barplot(x="Sex", y="Survived", data=train)
print("Percentage of females who survived:", train["Survived"][train["Sex"] == 'female'].value_counts(normalize = True)[1]*100)
print("Percentage of males who survived:", train["Survived"][train["Sex"] == 'male'].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of females who survived: 74.20382165605095
# Percentage of males who survived: 18.890814558058924

# %% [markdown]
# **Kesimpulan** = wanita memiliki probabilitas selamat lebih tinggi dibandingkan pria.

# %% [markdown]
# ### Pclass

# %%
sns.barplot(x="Pclass", y="Survived", data=train)

print("Presentase Pclass = 1 yang selamat:", train["Survived"][train["Pclass"] == 1].value_counts(normalize = True)[1]*100)

print("Presentase Pclass = 2 yang selamat:", train["Survived"][train["Pclass"] == 2].value_counts(normalize = True)[1]*100)

print("Presentase Pclass = 3 yang selamat:", train["Survived"][train["Pclass"] == 3].value_counts(normalize = True)[1]*100)
# Out:
# Presentase Pclass = 1 yang selamat: 62.96296296296296
# Presentase Pclass = 2 yang selamat: 47.28260869565217
# Presentase Pclass = 3 yang selamat: 24.236252545824847

# %% [markdown]
# **Kesimpulan** = orang dengan kelas ekonomi yang lebih tinggi memiliki probabilitas selamat lebih tinggi juga.
# - Pclass 1 = 62.96%
# - Pclass 2 = 47.28%
# - Pclass 3 = 24.2%

# %% [markdown]
# ### SibSp (with Siblings/Spouse)

# %%
sns.barplot(x="SibSp", y="Survived", data=train)

print("Survival rate SibSp = 0: ", train["Survived"][train["SibSp"] == 0].value_counts(normalize = True)[1]*100)
print("Survival rate SibSp = 1: ", train["Survived"][train["SibSp"] == 1].value_counts(normalize = True)[1]*100)
print("Survival rate SibSp = 2: ", train["Survived"][train["SibSp"] == 2].value_counts(normalize = True)[1]*100)
# Out:
# Survival rate SibSp = 0:  34.53947368421053
# Survival rate SibSp = 1:  53.588516746411486
# Survival rate SibSp = 2:  46.42857142857143

# %% [markdown]
# **Kesimpulan** = penumpang dengan jumlah saudara/pasangan yang lebih banyak akan memiliki kemungkinan selamat lebih kecil. Tetapi, penumpang yang pergi sendirian lebih mungkin untuk selamat dibandingkan penumpang dengan 3 atau 4 saudara/pasangan.

# %% [markdown]
# ### Parch

# %%
# Parch vs. survival
sns.barplot(x="Parch", y="Survived", data=train)
plt.show()

# %% [markdown]
# People with less than four parents or children aboard are more likely to survive than those with four or more. Again, people traveling alone are less likely to survive than those with 1-3 parents or children.

# %% [markdown]
# ### Age

# %%
# sort umur dari yang terkecil ke terbesar dan memasukkan ke 8 kategori
train["Age"] = train["Age"].fillna(-0.5) # isi data null pada train dengan -0.5
test["Age"] = test["Age"].fillna(-0.5) # isi data null pada test dengan -0.5
bins = [-1, 0, 5, 12, 18, 24, 35, 60, np.inf] # bins untuk membagi umur

labels = ['Unknown', 'Baby', 'Child', 'Teenager', 'Student', 'Young Adult', 'Adult', 'Senior']
train['AgeGroup'] = pd.cut(train["Age"], bins, labels = labels)
test['AgeGroup'] = pd.cut(test["Age"], bins, labels = labels)

# bar plot Age vs. survival
sns.barplot(x="AgeGroup", y="Survived", data=train)
plt.show()

# %% [markdown]
# **Kesimpulan** = bayi memiliki survival rate paling tinggi di antara kategori umur lain.

# %% [markdown]
# ### Cabin

# %%
train["CabinBool"] = (train["Cabin"].notnull().astype('int'))
test["CabinBool"] = (test["Cabin"].notnull().astype('int'))

#calculate percentages of CabinBool vs. survived
print("Percentage of CabinBool = 1 who survived:", train["Survived"][train["CabinBool"] == 1].value_counts(normalize = True)[1]*100)

print("Percentage of CabinBool = 0 who survived:", train["Survived"][train["CabinBool"] == 0].value_counts(normalize = True)[1]*100)
#draw a bar plot of CabinBool vs. survival
sns.barplot(x="CabinBool", y="Survived", data=train)
plt.show()
# Out:
# Percentage of CabinBool = 1 who survived: 66.66666666666666
# Percentage of CabinBool = 0 who survived: 29.985443959243085

# %% [markdown]
# **Kesimpulan** = ada penumpang yang tidak memiliki record data cabin. Orang yang memiliki record data cabin mereka adalah orang dengan kelas ekonomi yang lebih tinggi. Maka dari itu, mereka lebih mungkin untuk selamat (sesuai dengan survival rate pada fitur Pclass)

# %% [markdown]
# ## 5) Membersihkan data (Data cleaning)
# Kita sudah melihat bahwa masih terdapat banyak data yang hilang pada dataset. Maka dari itu, data cleaning perlu dilakukan untuk mengatasi kehilangan data tersebut dan memilah mana informasi-informasi yang penting dan relevan untuk penelitian.

# %% [markdown]
# ### test data

# %%
test.describe(include="all")
# Out:
#         PassengerId      Pclass              Name   Sex         Age  \
# count    418.000000  418.000000               418   418  418.000000
# unique          NaN         NaN               418     2         NaN
# top             NaN         NaN  Kelly, Mr. James  male         NaN
# freq            NaN         NaN                 1   266         NaN
# mean    1100.500000    2.265550               NaN   NaN   23.941388
# std      120.810458    0.841838               NaN   NaN   17.741080
# min      892.000000    1.000000               NaN   NaN   -0.500000
# 25%      996.250000    1.000000               NaN   NaN    9.000000
# 50%     1100.500000    3.000000               NaN   NaN   24.000000
# 75%     1204.750000    3.000000               NaN   NaN   35.750000
# max     1309.000000    3.000000               NaN   NaN   76.000000
#
#              SibSp       Parch    Ticket        Fare            Cabin  \
# count   418.000000  418.000000       418  417.000000               91
# ...

# %% [markdown]
# **Insights**
# * total 418 penumpang.
# * 1 value dari Fare hilang
# * 20.5% value dari Age hilang (harus diisi karena Age adalah fitur yang relevan)

# %% [markdown]
# ### Drop Cabin & Ticket
# Fitur cabin dan tiket tidak relevan dalam penelitian ini.

# %%
train = train.drop(['Cabin'], axis = 1)
test = test.drop(['Cabin'], axis = 1)

train = train.drop(['Ticket'], axis = 1)
test = test.drop(['Ticket'], axis = 1)

# %% [markdown]
# ### Embarked Feature
# Mengisi data Embarked yang hilang dengan tujuan kota yang peling banyak, yaitu Southampton

# %%
#now we need to fill in the missing values in the Embarked feature
print("Banyak penumpang yang turun di Southampton (S):")
southampton = train[train["Embarked"] == "S"].shape[0]
print(southampton)

print("Banyak penumpang yang turun di Cherbourg (C):")
cherbourg = train[train["Embarked"] == "C"].shape[0]
print(cherbourg)

print("Banyak penumpang yang turun di Queenstown (Q):")
queenstown = train[train["Embarked"] == "Q"].shape[0]
print(queenstown)


train = train.fillna({"Embarked": "S"})
# Out:
# Banyak penumpang yang turun di Southampton (S):
# 644
# Banyak penumpang yang turun di Cherbourg (C):
# 168
# Banyak penumpang yang turun di Queenstown (Q):
# 77

# %% [markdown]
# ### Age Feature

# %% [markdown]
# Mengisi data pada fitur Age yang hilang

# %%
# data gabungan train & test
combine = [train, test]

# extract title dari nama
for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

pd.crosstab(train['Title'], train['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
# banyak Title yang tidak umum digunakan, maka akan diganti dengan Title nama yang lebih umum seperti Mr, Mrs, Miss, Royal, dan Rare (untuk title yang jarang muncul)

for dataset in combine:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Capt', 'Col',
    'Don', 'Dr', 'Major', 'Rev', 'Jonkheer', 'Dona'], 'Rare')
    
    dataset['Title'] = dataset['Title'].replace(['Countess', 'Lady', 'Sir'], 'Royal')
    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')

train[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.285714
# 5   Royal  1.000000

# %%
# ubah Title menjadi angka supaya bisa diolah ke ML model

title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Royal": 5, "Rare": 6}
for dataset in combine:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked     AgeGroup  CabinBool  Title
# 0      0   7.2500        S      Student          0      1
# 1      0  71.2833        C        Adult          1      3
# 2      0   7.9250        S  Young Adult          0      2
# 3      0  53.1000        S  Young Adult          1      3
# ...

# %%
mr_age = train[train["Title"] == 1]["AgeGroup"].mode() #Young Adult
miss_age = train[train["Title"] == 2]["AgeGroup"].mode() #Student
mrs_age = train[train["Title"] == 3]["AgeGroup"].mode() #Adult
master_age = train[train["Title"] == 4]["AgeGroup"].mode() #Baby
royal_age = train[train["Title"] == 5]["AgeGroup"].mode() #Adult
rare_age = train[train["Title"] == 6]["AgeGroup"].mode() #Adult

age_title_mapping = {1: "Young Adult", 2: "Student", 3: "Adult", 4: "Baby", 5: "Adult", 6: "Adult"}

for x in range(len(train["AgeGroup"])):
    if train["AgeGroup"][x] == "Unknown":
        train["AgeGroup"][x] = age_title_mapping[train["Title"][x]]
        
for x in range(len(test["AgeGroup"])):
    if test["AgeGroup"][x] == "Unknown":
        test["AgeGroup"][x] = age_title_mapping[test["Title"][x]]

# map tiap kategori umur ke angka
age_mapping = {'Baby': 1, 'Child': 2, 'Teenager': 3, 'Student': 4, 'Young Adult': 5, 'Adult': 6, 'Senior': 7}
train['AgeGroup'] = train['AgeGroup'].map(age_mapping)
test['AgeGroup'] = test['AgeGroup'].map(age_mapping)

train.head()

train = train.drop(['Age'], axis = 1)
test = test.drop(['Age'], axis = 1)

# %% [markdown]
# ### Name Feature
# Fitur Name tidak diperlukan lagi karena sudah diekstrak berdasarkan Title.

# %%
train = train.drop(['Name'], axis = 1)
test = test.drop(['Name'], axis = 1)

# %% [markdown]
# ### Ubah Sex, Embarked, dan Fare ke categorical value

# %%
# SEX
# 0 = pria; 1 = wanita
sex_mapping = {"male": 0, "female": 1}
train['Sex'] = train['Sex'].map(sex_mapping)
test['Sex'] = test['Sex'].map(sex_mapping)

# EMBARKED
embarked_mapping = {"S": 1, "C": 2, "Q": 3}
train['Embarked'] = train['Embarked'].map(embarked_mapping)
test['Embarked'] = test['Embarked'].map(embarked_mapping)

# FARE
for x in range(len(test["Fare"])):
    if pd.isnull(test["Fare"][x]):
        pclass = test["Pclass"][x] #Pclass = 3
        test["Fare"][x] = round(train[train["Pclass"] == pclass]["Fare"].mean(), 4)
        
#map Fare values into groups of numerical values
train['FareBand'] = pd.qcut(train['Fare'], 4, labels = [1, 2, 3, 4])
test['FareBand'] = pd.qcut(test['Fare'], 4, labels = [1, 2, 3, 4])

#drop Fare values
train = train.drop(['Fare'], axis = 1)
test = test.drop(['Fare'], axis = 1)

train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  SibSp  Parch  Embarked  AgeGroup  \
# 0            1         0       3    0      1      0         1       4.0
# 1            2         1       1    1      1      0         2       6.0
# 2            3         1       3    1      0      0         1       5.0
# 3            4         1       1    1      1      0         1       5.0
# 4            5         0       3    0      0      0         1       5.0
#
#    CabinBool  Title FareBand
# 0          0      1        1
# 1          1      3        4
# 2          0      2        2
# 3          1      3        4
# 4          0      1        2

# %% [markdown]
# ## 6) Memilih model machine learning

# %% [markdown]
# ### Split training data
# Menggunakan 20% training data untuk mengetest akurasi masing-masing ML model.

# %%
from sklearn.model_selection import train_test_split

predictors = train.drop(['Survived', 'PassengerId'], axis=1)
target = train["Survived"]
x_train, x_val, y_train, y_val = train_test_split(predictors, target, test_size = 0.20, random_state = 0)

# %% [markdown]
# ### Model Machine Learning yang Dites
#
# * Gaussian Naive Bayes
# * Logistic Regression
# * Support Vector Machines
# * Perceptron
# * Decision Tree Classifier
# * Random Forest Classifier
# * KNN or k-Nearest Neighbors
# * Stochastic Gradient Descent
# * Gradient Boosting Classifier
#
# ### Untuk setiap model, dilakukan step sebagai berikut:
# 1. set model
# 2. fit model dengan 80% training data
# 3. prediksi 20%-nya
# 4. hitung akurasi

# %% [markdown]
# ### Gaussian Naive Bayes
# Naive Bayes adalah algoritma klasifikasi yang didasari oleh teorema Bayes. Jika menggunakan model ini, maka fitur-fitur di dalam data dianggap independen satu sama lain.
#
# Pada eksplorasi sebelumnya, kita tahu bahwa penumpang yang lebih mungkin selamat adalah penumpang wanita. Meskipun begitu, Naive Bayes classifier menganggap tidak ada hubungan antara survival rate dan sex penumpang.

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

gaussian = GaussianNB()
gaussian.fit(x_train, y_train)
y_pred = gaussian.predict(x_val)
acc_gaussian = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_gaussian)
# Out:
# 78.68

# %% [markdown]
# ### Logistic Regression
# Logistic Regression adalah model yang digunakan untuk masalah binary classification. Model ini kurang cocok digunakan pada dataset ini karena lebih baik menggunakan softmax function (multi-class classification).

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(x_train, y_train)
y_pred = logreg.predict(x_val)
acc_logreg = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_logreg)
# Out:
# 79.7

# %% [markdown]
# ### Support Vector Machines (SVM)
# SVM adalah model binary classification dengan dasar linear classifier.

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train, y_train)
y_pred = svc.predict(x_val)
acc_svc = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_svc)
# Out:
# 82.74

# %% [markdown]
# ### Linear SVM
# Pada linear SVM, digunakan garis-garis lurus untuk membagi data ke beberapa kelompok. Tujuan dari SVM adalah untuk mencari garis lurus dengan jarak paling jauh dari point-point (support vectors) tetapi tetap membagi data dengan baik. Hal ini bertujuan untuk menghasilkan model dengan generalisasi yang baik.

# %%
from sklearn.svm import LinearSVC

linear_svc = LinearSVC()
linear_svc.fit(x_train, y_train)
y_pred = linear_svc.predict(x_val)
acc_linear_svc = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_linear_svc)
# Out:
# 78.68

# %% [markdown]
# ### Perceptron
# Perceptron adalah algoritma machine learning (supervised learning) yang membutuhkan binary classification. Perceptron juga merupakan single-layer neural network dengan empat parameter utama, yaitu:
# - input values
# - weights and biases
# - net sum
# - activation function

# %%
from sklearn.linear_model import Perceptron

perceptron = Perceptron()
perceptron.fit(x_train, y_train)
y_pred = perceptron.predict(x_val)
acc_perceptron = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_perceptron)
# Out:
# 78.68

# %% [markdown]
# ### Decision Tree
# Decision Tree adalah algoritma penentuan keputusan. Disebut decision tree karena strukturnya mirip seperti pohon.
# Analisis dimulai dari node root. Dari root tersebut, tentukan aspek apa yang akan diklasifikasi, begitu seterusnya sampai ditemukan kesimpulan.
#
# Struktur dari decision tree terdiri atas:
# - Root node
# - Internal node
# - Leaf node

# %%
from sklearn.tree import DecisionTreeClassifier

decisiontree = DecisionTreeClassifier()
decisiontree.fit(x_train, y_train)
y_pred = decisiontree.predict(x_val)
acc_decisiontree = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_decisiontree)
# Out:
# 80.2

# %% [markdown]
# ### Random Forest
# Random Forest adalah algoritma yang menggabungkan banyak decision tree untuk membuat prediksi yang lebih stabil dan akurat.
# Cara kerja:
# 1. Bagi training data menjadi beberapa subset
# 2. Dari masing-masing subset, buat decision tree-nya.
# 3. Setelah mendapatkan prediksi dari masing-masing decision tree, prediksi tersebut kemudian diagregasi untuk mendapatkan **final prediction**.
#
#
# Random Forest dapat digunakan untuk masalah klasifikasi maupun regresi.

# %%
from sklearn.ensemble import RandomForestClassifier

randomforest = RandomForestClassifier()
randomforest.fit(x_train, y_train)
y_pred = randomforest.predict(x_val)
acc_randomforest = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_randomforest)
# Out:
# 84.26

# %% [markdown]
# ### K-Nearest Neighbors (KNN)
# KNN adalah algoritma machine learning yang paling simple. Algoritma ini menghasilkan prediksi berdasarkan "tetangga" pada training set. Nilai k adalah banyak sample yang digunakan untuk melakukan algoritma KNN.
#
# Semakin besar nilai k, maka kemungkinan untuk underfitting juga semakin besar. Semakin kecil nilai k, maka kemungkinan untuk overfitting juga semakin besar.
#
# Untuk menghasilkan prediksi KNN yang baik, dibutuhkan komputasi yang besar.

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
y_pred = knn.predict(x_val)
acc_knn = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_knn)
# Out:
# 82.74

# %% [markdown]
# ### Stochastic Gradient Descent
# Stochastic Gradient Descent adalah algoritma yang bekerja dengan cara memilih secara random salah satu sample di dataset untuk _meng-update_ weight berdasarkan nilai gradien pada poin saat itu.

# %%
from sklearn.linear_model import SGDClassifier

sgd = SGDClassifier()
sgd.fit(x_train, y_train)
y_pred = sgd.predict(x_val)
acc_sgd = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_sgd)
# Out:
# 56.35

# %% [markdown]
# ## Perbandingan akurasi yang didapat dari semua model

# %%
models = pd.DataFrame({
    'Model': ['SVM', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 'Perceptron', 'Linear SVC', 
              'Decision Tree', 'Stochastic Gradient Descent'],
    'Score': [acc_svc, acc_knn, acc_logreg, 
              acc_randomforest, acc_gaussian, acc_perceptron,acc_linear_svc, acc_decisiontree,
              acc_sgd]})
models.sort_values(by='Score', ascending=False) # urutkan dari yang tertinggi ke terendah
# Out:
#                          Model  Score
# 3                Random Forest  84.26
# 0                          SVM  82.74
# 1                          KNN  82.74
# 7                Decision Tree  80.20
# 2          Logistic Regression  79.70
# 4                  Naive Bayes  78.68
# 5                   Perceptron  78.68
# 6                   Linear SVC  78.68
# 8  Stochastic Gradient Descent  56.35

# %% [markdown]
# ### Kesimpulan: kita dapat menggunakan model **Random Forest** atau **Gradient Boosting Classifier** untuk mendapatkan prediksi yang lebih akurat.
